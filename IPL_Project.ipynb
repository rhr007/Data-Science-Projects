# %% [markdown]
# <a href="https://colab.research.google.com/github/rhr007/Data-Science-Projects/blob/main/IPL_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_set = pd.read_csv("matches.csv")
data_set.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
data_set.shape # This provides the number of rows and coloums of the data set
# Out:
# (1095, 20)

# %%
data_set['player_of_match'].value_counts() # Frequency list of Man of the Match
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64

# %%
# Top 10 players from Man of the Match list
data_set['player_of_match'].value_counts()[0:10]

# My observation: In this case 10 is inclusive
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# SP Narine         15
# Name: count, dtype: int64

# %%
top_10 = data_set['player_of_match'].value_counts()[0:10]
names = top_10.keys()
values = top_10.values
# Out:
# [25 22 19 18 18 17 16 16 16 15]

# %%
plt.bar(names, values, color='g')
plt.show()

# %%
data_set.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
toss_winner = data_set['toss_winner'].value_counts()[0:5]

plt.figure(figsize=(10, 5))
plt.bar(toss_winner.keys(), toss_winner, color='b')
plt.show()

# %%
data_set['season'].value_counts()
# Out:
# season
# 2013       76
# 2023       74
# 2012       74
# 2022       74
# 2011       73
# 2024       71
# 2018       60
# 2021       60
# 2020/21    60
# 2019       60
# 2016       60
# 2014       60
# 2009/10    60
# 2017       59
# 2015       59
# 2007/08    58
# 2009       57
# Name: count, dtype: int64

# %%
data_set['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
import numpy as np

sum = np.sum(data_set['toss_winner'] == data_set['winner'])
print(sum)
# Out:
# 554

# %%
print(554/data_set.shape[0])
# Out:
# 0.5059360730593607
